# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import json

# %%
csv_dir="./logs"
program_file_dir="."

# %%
# get all program files that end with .py
program_files = [f for f in os.listdir(program_file_dir) if f.endswith(".py")]

# %%
program = program_files[0].split(".")[0]
same_program_csv_dir=os.path.join(csv_dir,program)
# samples = total number of runs for each program
samples = len(os.listdir(same_program_csv_dir))

# %%
op_to_func = {}

# loop through csv files in csv_dir
for program_ in program_files:
    program = program_.split(".")[0]
    same_program_csv_dir=os.path.join(csv_dir,program)
    common_funcs_per_op = set()
    c_func_to_count = {}
    print(f"Reading {same_program_csv_dir}")
    for csv_file in os.listdir(same_program_csv_dir):
        # read csv file
        f = open(os.path.join(same_program_csv_dir,csv_file))
        lines = []
        start_append = False
        # read lines until "HOTTEST FUNCTIONS (Sort Event - CPU_TIME)"
        for line in f.readlines():
            if "HOTTEST FUNCTIONS (Sort Event - CPU_TIME)" in line:
                start_append = True
            elif start_append:
                if line == "\n":
                # if start append is true and line is newline then set start_append to False
                    break
                else:
                    split_line = line.split(',')
                    if len(split_line) > 3:
                            split_line = [",".join(split_line[:-2])] + split_line[-2:]
                    lines.append(split_line)
            
        df = pd.DataFrame(lines[1:], columns=lines[0])

        # remove '"' from df['FUNCTION'].astype(str)
        df['FUNCTION'] = df['FUNCTION'].astype(str).str.strip('"')
        # remove '\n' from df['Module\n'].astype(str)
        df['Module\n'] = df['Module\n'].astype(str).str.strip('\n').str.strip('"')
        # Split 'Module\n' by '/' and take the last element
        df['Module\n'] = df['Module\n'].str.split('/').str[-1]

        # merge two columns with "|" as separator
        df["full_func"] = df['FUNCTION'].astype(str) + "|" + df['Module\n'].astype(str).str.strip('\n')
        column_values = set(df["full_func"].values)        
        for func in df["full_func"].values:
            # if function is not in the dictionary, add it
            if func not in c_func_to_count:
                c_func_to_count[func] = 1
            # else increment the count
            else:
                c_func_to_count[func] += 1
    for func in c_func_to_count:
        # i.e. present in more than half of the samples
        # if c_func_to_count[func] > samples//2:
        common_funcs_per_op.add(func)
    op_to_func[program] = list(common_funcs_per_op)
    print(f"Common functions for {program} are {common_funcs_per_op}")
# Out:
# Reading ./logs/Normalize
# Common functions for Normalize are {'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#14}::operator()() const::{lambda(float)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#4}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so', 'libgomp-a34b3233.so.1!0x00018b10|libgomp-a34b3233.so.1', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#3}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#3}::operator()() const::{lambda()#3}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so', 'libgomp-a34b3233.so.1!0x00018b16|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018b21|libgomp-a34b3233.so.1', 'void at::native::AVX2::vectorized_loop<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&>(char**, long, long, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&)|libtorch_cpu.so', 'libgomp-a34b3233.so.1!0x00018b13|libgomp-a34b3233.so.1', 'gomp_barrier_wait_end|libgomp.so.1.0.0', 'libgomp-a34b3233.so.1!0x00018c88|libgomp-a34b3233.so.1', 'deduce_unreachable|python3.11', 'gomp_team_barrier_wait_end|libgomp.so.1.0.0', 'libgomp-a34b3233.so.1!0x00018c8e|libgomp-a34b3233.so.1', '__tls_get_addr|ld-2.31.so', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::add_kernel(at::TensorIteratorBase&, c10::Scalar const&)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::add_kernel(at::TensorIteratorBase&, c10::Scalar const&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so', 'libgomp-a34b3233.so.1!0x00018c99|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018c8b|libgomp-a34b3233.so.1'}
# Reading ./logs/RandomResizedCrop
# Common functions for RandomResizedCrop are {'ImagingPaste|_imaging.cpython-311-x86_64-linux-gnu.so', 'ImagingResampleVertical_8bpc|_imaging.cpython-311-x86_64-linux-gnu.so', '__memcpy_avx_unaligned_erms|libc-2.31.so', 'ImagingResampleVertical_8bpc|_imaging.cpython-39-x86_64-linux-gnu.so', 'deduce_unreachable|python3.9', '_PyEval_EvalFrameDefault|python3.9', 'ImagingResampleHorizontal_8bpc|_imaging.cpython-39-x86_64-linux-gnu.so', 'ImagingResampleHorizontal_8bpc|_imaging.cpython-311-x86_64-linux-gnu.so'}
# Reading ./logs/ToTensor
# Common functions for ToTensor are {'set_traverse|python3.9', 'libgomp-a34b3233.so.1!0x00018b16|libgomp-a34b3233.so.1', 'void at::native::AVX2::vectorized_loop<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&>(char**, long, long, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&)|libtorch_cpu.so', 'libgomp-a34b3233.so.1!0x00018c88|libgomp-a34b3233.so.1', 'func_traverse|python3.11', 'libgomp-a34b3233.so.1!0x00018c99|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018c8b|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018b10|libgomp-a34b3233.so.1', 'subtype_traverse|python3.9', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so', 'descr_traverse|python3.9', 'libgomp-a34b3233.so.1!0x00018b21|libgomp-a34b3233.so.1', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::TensorIteratorBase::loop_2d_from_1d<at::native::AVX2::copy_kernel(at::TensorIterator&, bool)::{lambda()#1}::operator()() const::{lambda()#15}::operator()() const::{lambda()#1}::operator()() const::{lambda()#9}::operator()() const::{lambda(char**, long const*, long)#1}>(at::native::AVX2::copy_kernel(at::TensorIterator&, bool)::{lambda()#1}::operator()() const::{lambda()#15}::operator()() const::{lambda()#1}::operator()() const::{lambda()#9}::operator()() const::{lambda(char**, long const*, long)#1} const&)::{lambda(char**, long const*, long, long)#1}>(long, char**, long const*, long, long)|libtorch_cpu.so', '_PyObject_GetMethod|python3.9', 'object_dealloc|python3.11', 'gomp_team_barrier_wait_end|libgomp.so.1.0.0', '_int_free|libc-2.31.so', 'list_traverse|python3.9', 'ImagingPackRGB|_imaging.cpython-311-x86_64-linux-gnu.so', 'visit_reachable|python3.11', 'ImagingPackRGB|_imaging.cpython-39-x86_64-linux-gnu.so', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so', 'dict_traverse|python3.9', 'stringlib_bytes_join.lto_priv.1|python3.11', '_PyArg_ParseTuple_SizeT|python3.9', 'at::TensorIteratorBase::serial_for_each(c10::function_ref<void (char**, long const*, long, long)>, at::Range) const|libtorch_cpu.so', 'libgomp-a34b3233.so.1!0x00018b13|libgomp-a34b3233.so.1', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#8}::operator()() const::{lambda(unsigned char)#1}, at::native::AVX2::di ...
# Reading ./logs/RandomHorizontalFlip
# Common functions for RandomHorizontalFlip are {'ImagingFlipLeftRight|_imaging.cpython-311-x86_64-linux-gnu.so', 'deduce_unreachable|python3.9', 'PyImport_ImportModuleLevelObject|python3.9', '_PyObject_GetMethod|python3.9', 'ImagingFlipLeftRight|_imaging.cpython-39-x86_64-linux-gnu.so'}
# Reading ./logs/Loader
# Common functions for Loader are {'decompress_onepass|libjpeg.so.9.5.0', 'ycc_rgb_convert|libjpeg.so.9.5.0', 'jpeg_fill_bit_buffer|libjpeg.so.9.5.0', '__memset_avx2_unaligned_erms|libc-2.31.so', 'ImagingUnpackRGB|_imaging.cpython-39-x86_64-linux-gnu.so', '_copy|_imaging.cpython-39-x86_64-linux-gnu.so', 'take_gil|python3.11', 'jpeg_read_scanlines|libjpeg.so.9.5.0', '_PyObject_GetMethod|python3.9', 'object_dealloc|python3.11', 'dictiter_iternextitem|python3.9', 'jpeg_idct_islow|libjpeg.so.9.5.0', 'PyObject_GetAttr|python3.11', '__memset_avx2_unaligned|libc-2.31.so', 'ImagingUnpackRGB|_imaging.cpython-311-x86_64-linux-gnu.so', 'jpeg_idct_16x16|libjpeg.so.9.5.0', '__memcpy_avx_unaligned_erms|libc-2.31.so', 'decode_mcu|libjpeg.so.9.5.0', 'deduce_unreachable|python3.9', 'sep_upsample|libjpeg.so.9.5.0'}
# Reading ./logs/Collation
# Common functions for Collation are {'libgomp-a34b3233.so.1!0x00018b16|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018c88|libgomp-a34b3233.so.1', 'method_traverse|python3.11', 'libgomp-a34b3233.so.1!0x00018c97|libgomp-a34b3233.so.1', 'func_traverse|python3.11', 'libgomp-a34b3233.so.1!0x000163e0|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018c99|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018c8b|libgomp-a34b3233.so.1', 'gomp_ialias_omp_get_num_threads|libgomp.so.1.0.0', 'libgomp-a34b3233.so.1!0x00018b10|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x000163e4|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018b21|libgomp-a34b3233.so.1', 'gomp_barrier_wait|libgomp.so.1.0.0', 'gomp_team_barrier_wait_end|libgomp.so.1.0.0', 'void at::internal::invoke_parallel<at::parallel_for<at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1}>(long, long, long, at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1} const&)::{lambda(long, long)#1}>(long, long, long, at::parallel_for<at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1}>(long, long, long, at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1} const&)::{lambda(long, long)#1} const)|libtorch_cpu.so', 'libgomp-a34b3233.so.1!0x00018b26|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018cab|libgomp-a34b3233.so.1', 'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#14}::operator()() const::{lambda(float)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#4}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so', 'type_traverse|python3.11', 'libgomp-a34b3233.so.1!0x00018bc0|libgomp-a34b3233.so.1', 'visit_reachable|python3.11', 'torch::autograd::generated::details::stack_jvp(c10::ArrayRef<at::Tensor>, long)|libtorch_cpu.so', 'slot_tp_init|python3.9', 'libgomp-a34b3233.so.1!0x00016415|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018b13|libgomp-a34b3233.so.1', 'dict_traverse|python3.11', 'libgomp-a34b3233.so.1!0x0000f43f|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x00018b1f|libgomp-a34b3233.so.1', 'libgomp-a34b3233.so.1!0x0000f45f|libgomp-a34b3233.so.1', 'gomp_barrier_wait_end|libgomp.so.1.0.0', 'tupletraverse|python3.11', 'libgomp-a34b3233.so.1!0x0000f467|libgomp-a34b3233.so.1', 'deduce_unreachable|python3.9', 'deduce_unreachable|python3.11', 'libgomp-a34b3233.so.1!0x00018c8e|libgomp-a34b3233.so.1', '_int_malloc|libc-2.31.so', 'gc_collect_main|python3.11'}

# %%
op_to_func
# Out:
# {'RandomResizedCrop': ['ImagingResampleHorizontal_8bpc|_imaging.cpython-39-x86_64-linux-gnu.so',
#   'deduce_unreachable|python3.9',
#   '_PyEval_EvalFrameDefault|python3.9',
#   'ImagingResampleVertical_8bpc|_imaging.cpython-39-x86_64-linux-gnu.so',
#   'ImagingResampleVertical_8bpc|_imaging.cpython-311-x86_64-linux-gnu.so',
#   'ImagingResampleHorizontal_8bpc|_imaging.cpython-311-x86_64-linux-gnu.so',
#   '__memcpy_avx_unaligned_erms|libc-2.31.so',
#   'ImagingPaste|_imaging.cpython-311-x86_64-linux-gnu.so'],
#  'Loader': ['sep_upsample|libjpeg.so.9.5.0',
#   '_copy|_imaging.cpython-39-x86_64-linux-gnu.so',
#   '_PyObject_GetMethod|python3.9',
#   '__memset_avx2_unaligned_erms|libc-2.31.so',
#   'jpeg_idct_16x16|libjpeg.so.9.5.0',
#   'ImagingUnpackRGB|_imaging.cpython-39-x86_64-linux-gnu.so',
#   'jpeg_idct_islow|libjpeg.so.9.5.0',
#   'decompress_onepass|libjpeg.so.9.5.0',
#   'dictiter_iternextitem|python3.9',
#   'jpeg_fill_bit_buffer|libjpeg.so.9.5.0',
#   'ycc_rgb_convert|libjpeg.so.9.5.0',
#   'deduce_unreachable|python3.9',
#   'PyObject_GetAttr|python3.11',
#   'jpeg_read_scanlines|libjpeg.so.9.5.0',
#   '__memset_avx2_unaligned|libc-2.31.so',
#   'take_gil|python3.11',
#   'decode_mcu|libjpeg.so.9.5.0',
#   'object_dealloc|python3.11',
#   '__memcpy_avx_unaligned_erms|libc-2.31.so',
#   'ImagingUnpackRGB|_imaging.cpython-311-x86_64-linux-gnu.so'],
#  'Collation': ['gomp_barrier_wait_end|libgomp.so.1.0.0',
#   'gomp_ialias_omp_get_num_threads|libgomp.so.1.0.0',
#   'deduce_unreachable|python3.11',
#   'func_traverse|python3.11',
#   'void at::internal::invoke_parallel<at::parallel_for<at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1}>(long, long, long, at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1} const&)::{lambda(long, long)#1}>(long, long, long, at::parallel_for<at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1}>(long, long, long, at::TensorIteratorBase::for_each(c10::function_ref<void (char**, long const*, long, long)>, long)::{lambda(long, long)#1} const&)::{lambda(long, long)#1} const)|libtorch_cpu.so',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#14}::operator()() const::{lambda(float)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#4}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'libgomp-a34b3233.so.1!0x00018c8e|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018bc0|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00016415|libgomp-a34b3233.so.1',
#   'method_traverse|python3.11',
#   'libgomp-a34b3233.so.1!0x000163e0|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x0000f467|libgomp-a34b3233.so.1',
#   '_int_malloc|libc-2.31.so',
#   'deduce_unreachable|python3.9',
#   'libgomp-a34b3233.so.1!0x000163e4|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018c97|libgomp-a34b3233.so.1',
#   'gomp_barrier_wait|libgomp.so.1.0.0',
#   'libgomp-a34b3233.so.1!0x00018b16|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b1f|libgomp-a34b3233.so.1',
#   'torch::autograd::generated::details::stack_jvp(c10::ArrayRef<at::Tensor>, long)|libtorch_cpu.so',
#   'libgomp-a34b3233.so.1!0x00018c99|libgomp-a34b3233.so.1',
#   'type_traverse|python3.11',
#   'gomp_team_barrier_wait_end|libgomp.so.1.0.0',
#   'libgomp-a34b3233.so.1!0x00018b26|libgomp-a34b3233.so.1',
#   'visit_reachable|python3.11',
#   'tupletraverse|python3.11',
#   'libgomp-a34b3233.so.1!0x00018b10|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x0000f43f|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018c8b|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018c88|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b21|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b13|libgomp-a34b3233.so.1',
#   'slot_tp_init|python3.9',
#   'libgomp-a34b3233.so.1!0x0000f45f|libgomp-a34b3233.so.1',
#   'gc_collect_main|python3.11',
#   'libgomp-a34b3233.so.1!0x00018cab|libgomp-a34b3233.so.1',
#   'dict_traverse|python3.11'],
#  'RandomHorizontalFlip': ['deduce_unreachable|python3.9',
#   '_PyObject_GetMethod|python3.9',
#   'PyImport_ImportModuleLevelObject|python3.9',
#   'ImagingFlipLeftRight|_imaging.cpython-311-x86_64-linux-gnu.so',
#   'ImagingFlipLeftRight|_imaging.cpython-39-x86_64-linux-gnu.so'],
#  'Normalize': ['gomp_barrier_wait_end|libgomp.so.1.0.0',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#3}::operator()() const::{lambda()#7}::operator()() const::{lambda(float)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#3}::operator()() const::{lambda()#3}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#14}::operator()() const::{lambda(float)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#4}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'libgomp-a34b3233.so.1!0x00018c8e|libgomp-a34b3233.so.1',
#   'deduce_unreachable|python3.11',
#   'libgomp-a34b3233.so.1!0x00018b10|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b16|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018c8b|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018c88|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b21|libgomp-a34b3233.so.1',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::add_kernel(at::TensorIteratorBase&, c10::Scalar const&)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::add_kernel(at::TensorIteratorBase&, c10::Scalar const&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'libgomp-a34b3233.so.1!0x00018c99|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b13|libgomp-a34b3233.so.1',
#   'gomp_team_barrier_wait_end|libgomp.so.1.0.0',
#   '__tls_get_addr|ld-2.31.so',
#   'void at::native::AVX2::vectorized_loop<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&>(char**, long, long, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&)|libtorch_cpu.so'],
#  'ToTensor': ['gomp_barrier_wait_end|libgomp.so.1.0.0',
#   '_PyObject_GetMethod|python3.9',
#   'dict_traverse|python3.9',
#   'deduce_unreachable|python3.11',
#   'stringlib_bytes_join.lto_priv.1|python3.11',
#   'func_traverse|python3.11',
#   'void at::native::AVX2::vectorized_loop<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&>(char**, long, long, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&)|libtorch_cpu.so',
#   'descr_traverse|python3.9',
#   'libgomp-a34b3233.so.1!0x00018c8e|libgomp-a34b3233.so.1',
#   'ImagingPackRGB|_imaging.cpython-311-x86_64-linux-gnu.so',
#   '_int_free|libc-2.31.so',
#   'at::TensorIteratorBase::serial_for_each(c10::function_ref<void (char**, long const*, long, long)>, at::Range) const|libtorch_cpu.so',
#   '_PyArg_ParseTuple_SizeT|python3.9',
#   '_PyBytes_Resize|python3.11',
#   '_int_malloc|libc-2.31.so',
#   'deduce_unreachable|python3.9',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#8}::operator()() const::{lambda(unsigned char)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#4}::operator()() const::{lambda(at::vec::AVX2::Vectorized<unsigned char>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'tupledealloc|python3.9',
#   'subtype_traverse|python3.9',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::TensorIteratorBase::loop_2d_from_1d<at::native::AVX2::copy_kernel(at::TensorIterator&, bool)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(char**, long const*, long)#1}>(at::native::AVX2::copy_kernel(at::TensorIterator&, bool)::{lambda()#1}::operator()() const::{lambda()#7}::operator()() const::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(char**, long const*, long)#1} const&)::{lambda(char**, long const*, long, long)#1}>(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'set_traverse|python3.9',
#   'at::TensorIteratorBase::compute_mem_overlaps(at::TensorIteratorConfig const&)|libtorch_cpu.so',
#   'libgomp-a34b3233.so.1!0x00018b16|libgomp-a34b3233.so.1',
#   'ImagingPackRGB|_imaging.cpython-39-x86_64-linux-gnu.so',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::TensorIteratorBase::loop_2d_from_1d<at::native::AVX2::copy_kernel(at::TensorIterator&, bool)::{lambda()#1}::operator()() const::{lambda()#15}::operator()() const::{lambda()#1}::operator()() const::{lambda()#9}::operator()() const::{lambda(char**, long const*, long)#1}>(at::native::AVX2::copy_kernel(at::TensorIterator&, bool)::{lambda()#1}::operator()() const::{lambda()#15}::operator()() const::{lambda()#1}::operator()() const::{lambda()#9}::operator()() const::{lambda(char**, long const*, long)#1} const&)::{lambda(char**, long const*, long, long)#1}>(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'libgomp-a34b3233.so.1!0x00018c99|libgomp-a34b3233.so.1',
#   'gomp_team_barrier_wait_end|libgomp.so.1.0.0',
#   'list_traverse|python3.9',
#   'visit_reachable|python3.11',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'do_mktuple|python3.11',
#   'object_dealloc|python3.11',
#   'stringlib_bytes_join.lto_priv.0|python3.9',
#   'libgomp-a34b3233.so.1!0x00018b10|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018c8b|libgomp-a34b3233.so.1',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#3}::operator()() const::{lambda()#1}::operator()() const::{lambda(unsigned char)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#3}::operator()() const::{lambda()#3}::operator()() const::{lambda(at::vec::AVX2::Vectorized<unsigned char>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so',
#   'libgomp-a34b3233.so.1!0x00018c88|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b21|libgomp-a34b3233.so.1',
#   'libgomp-a34b3233.so.1!0x00018b13|libgomp-a34b3233.so.1',
#   'dict_traverse|python3.11',
#   'tupletraverse|python3.11',
#   '__memcpy_avx_unaligned_erms|libc-2.31.so',
#   'void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so']}

# %%
def find_common_cpp_func(op_to_func):
    # find functions found in other ops
    common_funcs_to_op = {}
    # loop through all programs
    for python_func in op_to_func.keys():
        # loop through all functions in the program
        for func in op_to_func[python_func]:
            # loop through all other programs
            for other_python_func in op_to_func.keys():
                # skip if the program is the same as the current program
                if other_python_func == python_func:
                    continue
                # if the function is found in other programs
                if func in op_to_func[other_python_func]:
                    # add the function to the set of common functions
                    if func not in common_funcs_to_op:
                        common_funcs_to_op[func] = [python_func,other_python_func]
                    elif python_func not in common_funcs_to_op[func] or other_python_func not in common_funcs_to_op[func]:
                        common_funcs_to_op[func].append(other_python_func)
    return common_funcs_to_op

# %%
common_funcs_to_op = find_common_cpp_func(op_to_func)
print("C/C++ functions that can be found in multiple python operations:")
for func in common_funcs_to_op.keys():
    print(f"\t{func}\n\t\t->\t{common_funcs_to_op[func]}")
# Out:
# C/C++ functions that can be found in multiple python operations:
# 	void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#14}::operator()() const::{lambda(float)#1}, at::native::AVX2::direct_copy_kernel(at::TensorIteratorBase&)::{lambda()#4}::operator()() const::{lambda()#4}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so
# 		->	['Normalize', 'Collation']
# 	libgomp-a34b3233.so.1!0x00018b10|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	void c10::function_ref<void (char**, long const*, long, long)>::callback_fn<at::native::AVX2::VectorizedLoop2d<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#2}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}> >(long, char**, long const*, long, long)|libtorch_cpu.so
# 		->	['Normalize', 'ToTensor']
# 	libgomp-a34b3233.so.1!0x00018b16|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	libgomp-a34b3233.so.1!0x00018b21|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	void at::native::AVX2::vectorized_loop<at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&>(char**, long, long, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#2}::operator()() const::{lambda(float, float)#1}&, at::native::(anonymous namespace)::div_true_kernel(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#1}::operator()() const::{lambda(at::vec::AVX2::Vectorized<float>, at::vec)#2}&)|libtorch_cpu.so
# 		->	['Normalize', 'ToTensor']
# 	libgomp-a34b3233.so.1!0x00018b13|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	gomp_barrier_wait_end|libgomp.so.1.0.0
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	libgomp-a34b3233.so.1!0x00018c88|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	deduce_unreachable|python3.11
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	gomp_team_barrier_wait_end|libgomp.so.1.0.0
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	libgomp-a34b3233.so.1!0x00018c8e|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	libgomp-a34b3233.so.1!0x00018c99|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	libgomp-a34b3233.so.1!0x00018c8b|libgomp-a34b3233.so.1
# 		->	['Normalize', 'ToTensor', 'Collation']
# 	__memcpy_avx_unaligned_erms|libc-2.31.so
# 		->	['RandomResizedCrop', 'ToTensor', 'Loader']
# 	deduce_unreachable|python3.9
# 		->	['RandomResizedCrop', 'ToTensor', 'RandomHorizontalFlip', 'Loader', 'Collation']
# 	func_traverse|python3.11
# 		->	['ToTensor', 'Collation']
# 	_PyObject_GetMethod|python3.9
# 		->	['ToTensor', 'RandomHorizontalFlip', 'Loader']
# 	object_dealloc|python3.11
# 		->	['ToTensor', 'Loader']
# 	visit_reachable|python3.11
# 		->	['ToTensor', 'Collation']
# 	dict_traverse|python3.11
# 		->	['ToTensor', 'Collation']
# 	tupletraverse|python3.11
# 		->	['ToTensor', 'Collation']
# 	_int_malloc|libc-2.31.so
# 		->	['ToTensor', 'Collation']

# %%
json_string = {'op_to_func':op_to_func,'common_funcs_to_op':common_funcs_to_op}
with open('mapping_funcs.json', 'w') as outfile:
    json.dump(json_string, outfile,indent=4)
